# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3083, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.402142
# Nearest to than: germaine, antidepressant, competes, schopenhauer, area, recieved, poe, clergyman,
# Nearest to these: letterboxed, lycopene, micron, quesada, people, euclidean, chissano, ethology,
# Nearest to however: unsolvable, multihulls, consistently, criticize, esau, stretched, gelling, bayer,
# Nearest to or: tenures, defines, siwa, thyestes, nate, arithmetica, anguish, yugoslav,
# Nearest to the: hamid, lancaster, campania, jinnah, reached, collectivization, vous, enriched,
# Nearest to if: carnivorous, imprecise, shrank, intolerable, calendars, subtype, cellular, appraisal,
# Nearest to in: desu, addict, dunkeld, idols, altitude, mailer, serves, weight,
# Nearest to at: hundred, inference, lufthansa, typographical, ottomans, macrocosm, alleles, automakers,
# Nearest to he: unconnected, hospital, telephone, charming, arrian, pink, sculptures, marianne,
# Nearest to have: higson, uttar, oddie, fifties, juxtaposition, immigrants, imap, illyrian,
# Nearest to new: ioan, normed, olympia, semitone, haran, monotonic, logic, nikaya,
# Nearest to for: encircling, utilitarian, balcony, nzenberg, convoluted, charms, drives, greenery,
# Nearest to five: stipulate, impassioned, parallels, hailstones, isosceles, powerpc, zine, polyphony,
# Nearest to a: patriarchal, canard, thief, facility, adl, energies, free, policymakers,
# Nearest to known: manx, kr, paces, sufism, ftc, psyche, narration, privatizing,
# Nearest to called: nantucket, simplest, axiom, nd, cod, overwhelming, anasazi, muster,
# Average loss at step 2000: 4.355041
# Average loss at step 4000: 3.862298
# Average loss at step 6000: 3.784594
# Average loss at step 8000: 3.685420
# Average loss at step 10000: 3.608882
# Nearest to than: antidepressant, poe, tricycle, or, nabla, nozzles, mobilization, recieved,
# Nearest to these: some, euclidean, many, letterboxed, mishna, chissano, gadget, sorting,
# Nearest to however: consistently, vine, erich, bass, leninism, torquay, pranksters, composition,
# Nearest to or: and, arithmetica, phone, dennett, mathcal, competence, countdown, apicomplexa,
# Nearest to the: this, its, his, a, their, hotline, an, rewrites,
# Nearest to if: appraisal, annette, lande, imprecise, bombarding, carnivorous, triad, time,
# Nearest to in: of, on, from, at, under, by, banishing, after,
# Nearest to at: in, from, saturated, on, kword, probate, sufi, tuning,
# Nearest to he: it, they, she, who, there, asis, scorned, referent,
# Nearest to have: had, be, are, tarantino, were, reich, nematic, has,
# Nearest to new: olympia, logic, ioan, haran, semitone, quattro, normed, sloop,
# Nearest to for: pistons, and, with, handily, hyphae, in, of, faber,
# Nearest to five: seven, six, eight, three, four, nine, zero, two,
# Nearest to a: the, this, pantheist, edinburgh, maximal, ockham, any, adl,
# Nearest to known: well, vers, narration, exerts, understandings, ftc, investigated, urim,
# Nearest to called: burton, made, defuse, proposes, established, overwhelming, dipped, necker,
# Average loss at step 12000: 3.600335
# Average loss at step 14000: 3.570411
# Average loss at step 16000: 3.411228
# Average loss at step 18000: 3.455993
# Average loss at step 20000: 3.539786
# Nearest to than: or, antidepressant, danny, equalization, mobilization, richest, piaget, penitentiary,
# Nearest to these: some, many, all, euclidean, such, mishna, other, they,
# Nearest to however: but, consistently, vine, moralistic, banishing, gatsby, bass, krylov,
# Nearest to or: and, than, arithmetica, snl, burr, parallel, gazing, flippers,
# Nearest to the: its, their, his, an, hotline, this, chifley, greetings,
# Nearest to if: when, but, espouses, appraisal, is, regime, then, clark,
# Nearest to in: at, on, from, by, under, dk, with, and,
# Nearest to at: in, on, from, and, clarifies, after, heralded, saturated,
# Nearest to he: it, she, they, who, there, praising, eventually, alcohols,
# Nearest to have: had, has, be, were, are, tarantino, electrostatic, reich,
# Nearest to new: logic, sloop, quattro, monotonic, haran, piccadilly, cgi, normed,
# Nearest to for: pistons, of, from, with, in, waterfalls, by, whatsoever,
# Nearest to five: eight, seven, six, four, three, zero, two, nine,
# Nearest to a: any, refrains, very, this, reining, another, maximal, tar,
# Nearest to known: well, exerts, such, vers, narration, appears, urim, understandings,
# Nearest to called: proposes, made, established, equus, defuse, burton, montego, cyclopedia,
# Average loss at step 22000: 3.495993
# Average loss at step 24000: 3.485586
# Average loss at step 26000: 3.481621
# Average loss at step 28000: 3.482396
# Average loss at step 30000: 3.501830
# Nearest to than: or, antidepressant, danny, rationalized, beni, specie, violates, richest,
# Nearest to these: some, many, several, such, all, are, their, they,
# Nearest to however: but, though, although, moralistic, vine, handguard, arithmetica, bass,
# Nearest to or: and, baird, but, than, gantry, gazing, kimchi, although,
# Nearest to the: their, its, his, any, a, some, kava, pastimes,
# Nearest to if: when, but, espouses, although, though, could, extra, do,
# Nearest to in: at, during, of, under, and, from, by, on,
# Nearest to at: in, deduces, on, after, under, navajo, marines, during,
# Nearest to he: she, it, they, who, there, never, scorned, impasse,
# Nearest to have: had, has, are, were, be, tarantino, electrostatic, having,
# Nearest to new: cancelling, logic, normed, monotonic, piccadilly, cgi, onion, major,
# Nearest to for: pistons, with, from, after, whatsoever, of, huddersfield, against,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to a: no, any, the, karabakh, every, boca, millie, his,
# Nearest to known: well, such, used, appears, vers, exerts, narration, designer,
# Nearest to called: proposes, equus, pounded, rejuvenation, burton, surrealist, montego, alc,
# Average loss at step 32000: 3.497419
# Average loss at step 34000: 3.493476
# Average loss at step 36000: 3.453344
# Average loss at step 38000: 3.300370
# Average loss at step 40000: 3.427207
# Nearest to than: or, equalization, beni, piaget, rationalized, pronunciations, specie, havenco,
# Nearest to these: many, some, several, such, they, all, numerous, mishna,
# Nearest to however: but, although, arithmetica, since, that, moralistic, though, krylov,
# Nearest to or: and, than, a, but, millsaps, symmetrically, julian, catacomb,
# Nearest to the: its, a, their, hotline, any, his, franchised, this,
# Nearest to if: when, is, where, for, can, espouses, then, could,
# Nearest to in: and, of, from, for, at, to, is, since,
# Nearest to at: on, during, in, deduces, against, discworld, navajo, southwestern,
# Nearest to he: she, it, they, there, who, i, eventually, then,
# Nearest to have: had, has, be, were, are, tarantino, include, colchis,
# Nearest to new: cancelling, manifesto, normed, snowflake, pres, monotonic, quattro, cgi,
# Nearest to for: from, in, of, with, if, blige, to, is,
# Nearest to five: six, seven, four, three, eight, nine, zero, two,
# Nearest to a: any, the, another, or, conformed, linnaeus, nn, recursion,
# Nearest to known: such, used, well, narration, vers, appears, measured, investigated,
# Nearest to called: pounded, proposes, where, equus, made, orbs, pemberton, per,
# Average loss at step 42000: 3.435840
# Average loss at step 44000: 3.451094
# Average loss at step 46000: 3.452367
# Average loss at step 48000: 3.354590
# Average loss at step 50000: 3.383202
# Nearest to than: or, beni, ishi, piaget, rationalized, and, times, rafter,
# Nearest to these: some, many, several, such, both, which, their, various,
# Nearest to however: but, although, that, though, since, while, where, arithmetica,
# Nearest to or: and, than, intv, catacomb, smack, piaget, but, while,
# Nearest to the: its, their, this, some, a, his, tilbury, an,
# Nearest to if: when, where, although, though, before, could, while, so,
# Nearest to in: during, from, of, within, on, since, at, classmate,
# Nearest to at: during, from, in, daddah, scalability, seawater, on, aversion,
# Nearest to he: she, it, they, who, there, this, eventually, impasse,
# Nearest to have: had, has, were, be, are, tarantino, colchis, teleportation,
# Nearest to new: cancelling, quattro, dione, spiritual, sensuous, logic, pres, direct,
# Nearest to for: whatsoever, pistons, hallstatt, huddersfield, drives, on, electoral, blige,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to a: another, any, the, no, boca, millie, bleachers, maximal,
# Nearest to known: used, such, possible, vers, well, appears, narration, part,
# Nearest to called: pounded, equus, proposes, wavefunctions, used, maneuvering, sanj, orbs,
# Average loss at step 52000: 3.435806
# Average loss at step 54000: 3.419584
# Average loss at step 56000: 3.440134
# Average loss at step 58000: 3.397453
# Average loss at step 60000: 3.394031
# Nearest to than: or, touching, and, beni, mobilization, rationalized, penitentiary, much,
# Nearest to these: many, some, several, such, both, certain, those, all,
# Nearest to however: but, although, since, that, though, which, when, while,
# Nearest to or: and, than, like, quantifier, but, while, including, reloaded,
# Nearest to the: their, a, its, this, any, his, some, aum,
# Nearest to if: when, where, before, though, although, could, then, without,
# Nearest to in: within, of, including, during, until, from, at, since,
# Nearest to at: during, in, deduces, scalability, under, landtag, hentai, occuring,
# Nearest to he: she, it, they, there, who, soon, eventually, bech,
# Nearest to have: has, had, were, are, include, be, teleportation, having,
# Nearest to new: cancelling, sloop, spiritual, cgi, direct, soul, feeding, centre,
# Nearest to for: of, pistons, blige, hallstatt, without, whatsoever, against, including,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to a: the, any, another, recursion, every, hasidic, insurers, reining,
# Nearest to known: used, such, possible, well, considered, regarded, narration, appears,
# Nearest to called: used, pounded, equus, known, orbs, volunteering, proposes, alc,
# Average loss at step 62000: 3.244369
# Average loss at step 64000: 3.254635
# Average loss at step 66000: 3.401633
# Average loss at step 68000: 3.394623
# Average loss at step 70000: 3.356820
# Nearest to than: or, beni, rationalized, mobilization, while, penitentiary, specie, touching,
# Nearest to these: some, such, many, several, certain, the, those, both,
# Nearest to however: but, although, though, while, that, where, when, since,
# Nearest to or: and, than, smack, while, the, capacitor, but, infinitesimals,
# Nearest to the: its, their, any, a, this, these, each, another,
# Nearest to if: when, though, where, before, although, could, because, while,
# Nearest to in: within, during, on, until, for, between, banishing, throughout,
# Nearest to at: deduces, during, predating, after, spliced, near, svalbard, richland,
# Nearest to he: she, it, they, there, who, we, soon, eventually,
# Nearest to have: had, has, are, were, be, include, provide, teleportation,
# Nearest to new: cancelling, conic, quattro, tux, sensuous, linguistic, bleed, feeding,
# Nearest to for: including, whatsoever, in, without, while, pistons, after, huddersfield,
# Nearest to five: six, four, seven, three, eight, zero, nine, two,
# Nearest to a: the, another, enough, any, refrains, conformed, every, signifies,
# Nearest to known: used, such, considered, possible, seen, regarded, narration, described,
# Nearest to called: ntsc, used, pounded, named, known, proposes, singhasari, sanj,
# Average loss at step 72000: 3.374650
# Average loss at step 74000: 3.349631
# Average loss at step 76000: 3.313569
# Average loss at step 78000: 3.347321
# Average loss at step 80000: 3.377639
# Nearest to than: but, much, or, rationalized, slightly, beni, somewhat, schemas,
# Nearest to these: several, many, such, both, some, those, various, certain,
# Nearest to however: but, although, that, though, while, where, arithmetica, since,
# Nearest to or: and, while, than, aelia, priced, rien, smack, sous,
# Nearest to the: its, their, a, hotline, his, kava, this, tilbury,
# Nearest to if: when, though, before, where, although, since, because, does,
# Nearest to in: on, during, until, within, at, since, after, whirlpool,
# Nearest to at: in, during, on, deduces, once, woodbridge, marines, richland,
# Nearest to he: she, it, they, there, who, we, soon, eventually,
# Nearest to have: had, has, were, are, include, be, provide, teleportation,
# Nearest to new: centre, cancelling, tux, quattro, budgetary, conference, snowflake, direct,
# Nearest to for: whatsoever, including, huddersfield, childress, dodge, pistons, after, although,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to a: the, every, conformed, reining, another, atomism, any, recursion,
# Nearest to known: used, regarded, possible, seen, such, defined, described, called,
# Nearest to called: referred, used, considered, named, known, ntsc, orbs, doing,
# Average loss at step 82000: 3.403638
# Average loss at step 84000: 3.407474
# Average loss at step 86000: 3.387599
# Average loss at step 88000: 3.351604
# Average loss at step 90000: 3.363085
# Nearest to than: acls, and, slightly, much, penitentiary, or, rationalized, touching,
# Nearest to these: several, many, some, such, both, all, are, multiple,
# Nearest to however: but, although, though, that, since, while, and, arithmetica,
# Nearest to or: and, rubinstein, magistrate, than, while, snl, legislatures, schedel,
# Nearest to the: its, a, this, boyz, any, his, every, their,
# Nearest to if: when, though, where, although, before, since, did, while,
# Nearest to in: within, during, until, at, under, between, from, batavians,
# Nearest to at: during, in, deduces, near, under, after, around, shorelines,
# Nearest to he: she, it, they, there, who, soon, we, eventually,
# Nearest to have: had, has, were, are, include, be, provide, having,
# Nearest to new: cgi, spiritual, cancelling, mitrokhin, conic, normed, similar, manual,
# Nearest to for: including, whatsoever, while, blige, of, pistons, after, against,
# Nearest to five: seven, three, eight, four, six, nine, zero, two,
# Nearest to a: any, the, every, recursion, another, conformed, atomism, gia,
# Nearest to known: used, possible, regarded, called, such, seen, available, described,
# Nearest to called: used, referred, known, named, considered, diem, proposes, ntsc,
# Average loss at step 92000: 3.399240
# Average loss at step 94000: 3.251103
# Average loss at step 96000: 3.357995
# Average loss at step 98000: 3.242771
# Average loss at step 100000: 3.359557
# Nearest to than: or, penitentiary, acls, dives, touching, beni, while, priory,
# Nearest to these: several, many, some, multiple, those, certain, all, various,
# Nearest to however: although, but, that, though, especially, where, while, which,
# Nearest to or: and, than, smack, snl, millsaps, while, without, clocking,
# Nearest to the: their, a, his, its, some, your, this, s,
# Nearest to if: when, though, where, before, although, while, because, since,
# Nearest to in: within, during, on, throughout, until, from, near, at,
# Nearest to at: on, during, deduces, after, in, near, colt, under,
# Nearest to he: she, it, they, there, who, we, soon, this,
# Nearest to have: had, has, are, include, were, tend, provide, be,
# Nearest to new: normed, cancelling, sensuous, specific, cgi, monotonic, talked, sravaka,
# Nearest to for: without, including, after, whatsoever, dodge, before, against, when,
# Nearest to five: seven, four, eight, six, three, nine, zero, two,
# Nearest to a: the, another, any, enough, reining, conformed, kilimanjaro, pflp,
# Nearest to known: possible, such, used, regarded, available, described, defined, seen,
# Nearest to called: named, referred, used, diem, humourous, ntsc, proposes, alkyl,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
